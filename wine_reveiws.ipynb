# %% [markdown]
# ## Wine Reviews

# %%
import pandas as pd

# %%
wine = pd.read_csv('Desktop/data_and_design/data/winemag-data-130k-v2.csv')

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129971 entries, 0 to 129970
# Data columns (total 14 columns):
# Unnamed: 0               129971 non-null int64
# country                  129908 non-null object
# description              129971 non-null object
# designation              92506 non-null object
# points                   129971 non-null int64
# price                    120975 non-null float64
# province                 129908 non-null object
# region_1                 108724 non-null object
# region_2                 50511 non-null object
# taster_name              103727 non-null object
# taster_twitter_handle    98758 non-null object
# title                    129971 non-null object
# variety                  129970 non-null object
# winery                   129971 non-null object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 13.9+ MB

# %%
chuck = wine[wine['price'] < 11]

# %%
chuck.nlargest(5, 'points')
# Out:
#        Unnamed: 0   country  \
# 10386       10386        US
# 11955       11955  Portugal
# 18310       18310  Portugal
# 26101       26101        US
# 27415       27415        US
#
#                                              description         designation  \
# 10386  A marvelous effort in a difficult year, this t...                 NaN
# 11955  A firm wine, based on dry tannins and some den...       Mural Reserva
# 18310  Orange peel aromas emerge on this delectable f...                 NaN
# 26101  With full ripeness, density and concentration,...  Winemaker's Select
# 27415  Gorgeous aromas of peach, pear, flower and spi...                 NaN
#
#        points  price             province              region_1  \
# 10386      91    9.0           Washington  Columbia Valley (WA)
# 11955      91   10.0                Douro                   NaN
# 18310      91   10.0  Moscatel de Setúbal                   NaN
# 26101      91    8.0           Washington  Columbia Valley (WA)
# ...

# %%
chuck.nsmallest(5, 'points')
# Out:
#        Unnamed: 0    country  \
# 3640         3640   Portugal
# 7333         7333         US
# 11085       11085     France
# 13782       13782      Chile
# 15609       15609  Argentina
#
#                                              description designation  points  \
# 3640   Aromas of strawberry sherbet are followed by s...     Estreia      80
# 7333   Too sweet by far for a table wine, with simple...         NaN      80
# 11085  A white this age should be fresh and crisp; th...         NaN      80
# 13782  Yeasty, melony and smelling like yellow mustar...  Left Coast      80
# 15609  Beware of funky labeled Malbecs because many d...         NaN      80
#
#        price          province    region_1          region_2  \
# 3640     8.0       Vinho Verde         NaN               NaN
# 7333    10.0        California  California  California Other
# 11085    8.0  Southwest France    Bergerac               NaN
# 13782    7.0             Chile         NaN               NaN
# ...

# %%
wine.groupby('country')['variety'].count().nlargest(5)
# Out:
# country
# US          54504
# France      22093
# Italy       19540
# Spain        6645
# Portugal     5691
# Name: variety, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
wine['points'].hist()

# %%
wine['points'].describe()
# Out:
# count    129971.000000
# mean         88.447138
# std           3.039730
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          91.000000
# max         100.000000
# Name: points, dtype: float64

# %%
larry = wine[wine['price'] < 18]

# %%
larry.nlargest(5, 'points')
# Out:
#        Unnamed: 0   country  \
# 19136       19136     Spain
# 23974       23974  Portugal
# 69526       69526        US
# 3844         3844     Italy
# 5509         5509   Austria
#
#                                              description  \
# 19136  A spectacularly sweet and rich bruiser, and on...
# 23974  Assobio is from a single vineyard in the Quint...
# 69526  This dry Moscato Giallo from Lodi is delicious...
# 3844   This gorgeous Chianti Classico boasts lively c...
# 5509   Grapefruit zest dominates this wine right now,...
#
#                            designation  points  price     province  \
# 19136  Pedro Ximenez 1827 Sweet Sherry      94   14.0    Andalucia
# 23974                          Assobio      94   13.0        Douro
# 69526                            Secco      94   16.0   California
# 3844                               NaN      93   16.0      Tuscany
# 5509                        Hundspoint      93   17.0  Weinviertel
#
# ...

# %%
larry.nsmallest(5, 'points')
# Out:
#       Unnamed: 0    country  \
# 3640        3640   Portugal
# 3641        3641      Chile
# 4556        4556      Italy
# 4557        4557      Spain
# 5905        5905  Argentina
#
#                                             description designation  points  \
# 3640  Aromas of strawberry sherbet are followed by s...     Estreia      80
# 3641  Fluffy, sweet aromas of peach, pear and vanill...     Reserve      80
# 4556  There's a thorny, almost raw quality of fruit ...   Rondineto      80
# 4557  With dusty, candied aromas, the bouquet on thi...    Demi Sec      80
# 5905  Ashy, green and funky smelling, then sweet, ch...         NaN      80
#
#       price          province        region_1 region_2        taster_name  \
# 3640    8.0       Vinho Verde             NaN      NaN         Roger Voss
# 3641   15.0      Maule Valley             NaN      NaN  Michael Schachner
# 4556   12.0     Central Italy  Colli Aprutini      NaN                NaN
# ...

# %%
wine.groupby('taster_name').mean()
# Out:
#                       Unnamed: 0     points      price
# taster_name
# Alexander Peartree  63922.395181  85.855422  29.053269
# Anna Lee C. Iijima  66204.838732  88.415629  29.790112
# Anne Krebiehl MW    66607.729715  90.562551  31.230135
# Carrie Dykes        76156.568345  86.395683  30.753623
# Christina Pickard   55558.166667  87.833333  29.333333
# Fiona Adams         70772.037037  86.888889  31.148148
# Jeff Jenssen        68237.240326  88.319756  22.234216
# Jim Gordon          66153.093129  88.626287  26.935507
# Joe Czerwinski      65015.720031  88.536235  35.175579
# Kerin O’Keefe       64745.919822  88.867947  41.953413
# Lauren Buzzeo       63925.799455  87.739510  24.492703
# Matt Kettmann       66232.972205  90.008686  38.642136
# Michael Schachner   64588.680851  86.907493  25.231155
# Mike DeSimone       68902.426070  89.101167  28.164683
# Paul Gregutt        64442.576689  89.082564  33.644873
# Roger Voss          64480.295524  88.708003  38.649960
# ...

# %%
1. top rated variety
2. top rated white under 14
3. top rated winery
4. top rated wine in france
5. lowest rated wine in US

# %%
wine.groupby('winery')['points'].count().nlargest(5)
# Out:
# winery
# Wines & Winemakers    222
# Testarossa            218
# DFJ Vinhos            215
# Williams Selyem       211
# Louis Latour          199
# Name: points, dtype: int64

# %%
france = wine['country'] == 'France'

# %%
wine['country'].value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# Canada                      257
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
red = ['pinot noir', 'malbec', 'merlot']
white = ['moscato', 'sauvignon blanc', 'reisling']

# %%
larry.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 5           5     Spain  Blackberry and raspberry aromas show a typical...
# 6           6     Italy  Here's a bright, informal red that opens with ...
#
#             designation  points  price           province  \
# 1              Avidagos      87   15.0              Douro
# 2                   NaN      87   14.0             Oregon
# 3  Reserve Late Harvest      87   13.0           Michigan
# 5          Ars In Vitro      87   15.0     Northern Spain
# 6               Belsito      87   16.0  Sicily & Sardinia
#
#               region_1           region_2         taster_name  \
# 1                  NaN                NaN          Roger Voss
# ...

# %%
larry.nlargest(15, 'points')
# Out:
#        Unnamed: 0       country  \
# 19136       19136         Spain
# 23974       23974      Portugal
# 69526       69526            US
# 3844         3844         Italy
# 5509         5509       Austria
# 9609         9609        France
# 9812         9812        Greece
# 12255       12255  South Africa
# 16178       16178        France
# 19140       19140         Spain
# 22871       22871      Portugal
# 26389       26389            US
# 30588       30588       Austria
# 37882       37882     Australia
# 43193       43193            US
#
#                                              description  \
# 19136  A spectacularly sweet and rich bruiser, and on...
# 23974  Assobio is from a single vineyard in the Quint...
# 69526  This dry Moscato Giallo from Lodi is delicious...
# 3844   This gorgeous Chianti Classico boasts lively c...
# 5509   Grapefruit zest dominates this wine right now,...
# 9609   A rich, Port-like wine that is full and concen...
# ...

# %%
wine.groupby('taster_name')['points'].mean().sort_values(ascending = False).plot(kind = 'bar', figsize = (9,5), title = 'Tasters Scores', color = 'blue') 
plt.ylim(80, 93)
# Out:
# (80, 93)
